# %%
# Import libraries
import numpy as np
import pandas as pd
from matplotlib.pyplot import plot as plt

# %%
# Read data from station "4"
df1 = pd.read_csv('data/4/TA00006.csv')
df2 = pd.read_csv('data/4/TA00009.csv')
df3 = pd.read_csv('data/4/TA00039.csv')
metadata = pd.read_csv('data/4/metadata.csv')

# %%
metadata
# Out:
#   station code                                               name country  \
# 0      TA00040  University for Development Studies, Navrongo C...      GH
# 1      TA00039                                   KNUST JHS Kumasi      GH
# 2      TA00006                             Nana Brentu SHTS Enchi      GH
# 3      TA00009                                Adehyeman SHS Amasu      GH
#
#    installation height (m)   latitude  longitude  elevation (m)      timezone
# 0                        2  10.884722  -1.090278            200  Africa/Accra
# 1                        2   6.684167  -1.568333            302  Africa/Accra
# 2                        2   5.811292  -2.825617            139  Africa/Accra
# 3                        2   7.224886  -2.782252            319  Africa/Accra

# %%
metadata.columns
# Out:
# Index(['station code', 'name', 'country', 'installation height (m)',
#        'latitude', 'longitude', 'elevation (m)', 'timezone'],
#       dtype='object')

# %%
metadata.rename(columns={'station code': 'station_code', 
                                  'installation height (m)': 'installation_height_(m)',
                                  'elevation (m)': 'elevation_(m)'}, inplace=True)

# %%
df1.head()
# Out:
#     timestamp (UTC)  atmosphericpressure (kPa)  precipitation (mm)  \
# 0  2015-08-19 09:40                     100.47                 0.0
# 1  2015-08-19 09:45                     100.47                 0.0
# 2  2015-08-19 09:50                     100.47                 0.0
# 3  2015-08-19 09:55                     100.47                 0.0
# 4  2015-08-19 10:00                     100.47                 0.0
#
#    radiation (W/m2)  relativehumidity (-)  temperature (degrees Celsius)  \
# 0              71.0                  0.82                           25.3
# 1               0.0                  0.82                           25.4
# 2               0.0                  0.82                           25.5
# 3               0.0                  0.82                           25.6
# 4               0.0                  0.81                           25.8
#
#    winddirection (degrees)  windgusts (m/s)  windspeed (m/s)
# 0                    237.0              1.6              0.4
# 1                    212.0              1.1              0.1
# 2                    286.0              0.1              0.0
# 3                    281.0              0.1              0.0
# 4                    275.0              0.1              0.1

# %%
df1.tail()
# Out:
#          timestamp (UTC)  atmosphericpressure (kPa)  precipitation (mm)  \
# 505167  2020-10-07 12:45                     100.13                 0.0
# 505168  2020-10-07 12:50                     100.11                 0.0
# 505169  2020-10-07 12:55                     100.08                 0.0
# 505170  2020-10-07 13:00                     100.07                 0.0
# 505171  2020-10-07 13:05                     100.06                 0.0
#
#         radiation (W/m2)  relativehumidity (-)  temperature (degrees Celsius)  \
# 505167             414.0                 0.898                           26.8
# 505168             448.0                 0.886                           27.2
# 505169             534.0                 0.878                           27.1
# 505170             571.0                 0.884                           27.1
# 505171             560.0                 0.884                           27.1
#
#         winddirection (degrees)  windgusts (m/s)  windspeed (m/s)
# 505167                     26.0             1.44             0.81
# 505168                     58.0             1.67             0.80
# 505169                     80.0             1.71             0.94
# 505170                     90.0             2.02             0.85
# 505171                    125.0             1.75             0.81

# %%
df1.columns
# Out:
# Index(['timestamp (UTC)', 'atmosphericpressure (kPa)', 'precipitation (mm)',
#        'radiation (W/m2)', 'relativehumidity (-)',
#        'temperature (degrees Celsius)', 'winddirection (degrees)',
#        'windgusts (m/s)', 'windspeed (m/s)'],
#       dtype='object')

# %%
df1.rename(columns={'timestamp (UTC)': 'timestamp_(UTC)', 
                              'atmosphericpressure (kPa)': 'atmospheric_pressure_(kPa)', 
                              'precipitation (mm)': 'precipitation_(mm)',
                              'radiation (W/m2)': 'radiation_(W/m2)', 
                              'relativehumidity (-)': 'relative_humidity_(-)',
                              'temperature (degrees Celsius)': 'temperature_(degrees_Celsius)', 
                              'winddirection (degrees)': 'wind_direction_(degrees)',
                              'windgusts (m/s)': 'wind_gusts_(m/s)', 
                              'windspeed (m/s)': 'wind_speed_(m/s)'
                             }, inplace=True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 505172 entries, 0 to 505171
# Data columns (total 9 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   timestamp_(UTC)                505172 non-null  object
#  1   atmospheric_pressure_(kPa)     504839 non-null  float64
#  2   precipitation_(mm)             486936 non-null  float64
#  3   radiation_(W/m2)               503691 non-null  float64
#  4   relative_humidity_(-)          504781 non-null  float64
#  5   temperature_(degrees_Celsius)  504765 non-null  float64
#  6   wind_direction_(degrees)       490607 non-null  float64
#  7   wind_gusts_(m/s)               490543 non-null  float64
#  8   wind_speed_(m/s)               490607 non-null  float64
# dtypes: float64(8), object(1)
# memory usage: 34.7+ MB

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
df1['timestamp_(UTC)'] = pd.to_datetime(df1['timestamp_(UTC)'])

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 505172 entries, 0 to 505171
# Data columns (total 9 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   timestamp_(UTC)                505172 non-null  datetime64[ns]
#  1   atmospheric_pressure_(kPa)     504839 non-null  float64
#  2   precipitation_(mm)             486936 non-null  float64
#  3   radiation_(W/m2)               503691 non-null  float64
#  4   relative_humidity_(-)          504781 non-null  float64
#  5   temperature_(degrees_Celsius)  504765 non-null  float64
#  6   wind_direction_(degrees)       490607 non-null  float64
#  7   wind_gusts_(m/s)               490543 non-null  float64
#  8   wind_speed_(m/s)               490607 non-null  float64
# dtypes: datetime64[ns](1), float64(8)
# memory usage: 34.7 MB

# %%
df1.describe()
# Out:
#        atmospheric_pressure_(kPa)  precipitation_(mm)  radiation_(W/m2)  \
# count               504839.000000       486936.000000     503691.000000
# mean                   100.018187            0.014156        156.237314
# std                      0.229115            0.205009        234.150710
# min                     79.970000            0.000000          0.000000
# 25%                     99.860000            0.000000          0.000000
# 50%                    100.020000            0.000000          0.000000
# 75%                    100.180000            0.000000        262.000000
# max                    100.780000           12.330000       1298.000000
#
#        relative_humidity_(-)  temperature_(degrees_Celsius)  \
# count          504781.000000                  504765.000000
# mean                0.863848                      26.467463
# std                 0.139262                       3.726919
# min                 0.040000                      13.300000
# 25%                 0.790000                      23.700000
# 50%                 0.910000                      25.400000
# 75%                 0.970000                      29.000000
# max                 1.000000                      47.000000
#
#        wind_direction_(degrees)  wind_gusts_(m/s)  wind_speed_(m/s)
# count             490607.000000     490543.000000     490607.000000
# mean                 186.961751          1.247717          0.596086
# std                   99.815171          0.759505          0.352999
# min                    0.000000          0.000000          0.000000
# 25%                   98.000000          0.700000          0.300000
# 50%                  205.000000          1.100000          0.500000
# 75%                  265.000000          1.630000          0.800000
# max                  359.000000         11.490000          8.800000

# %%
# Drop rows with any NA value to avoid us guessing values that might be wrong
df1.dropna(inplace=True)

# %%
df1.describe()
# Out:
#        atmospheric_pressure_(kPa)  precipitation_(mm)  radiation_(W/m2)  \
# count               472513.000000       472513.000000     472513.000000
# mean                   100.024204            0.011345        156.346628
# std                      0.221172            0.174647        234.534496
# min                     99.290000            0.000000          0.000000
# 25%                     99.870000            0.000000          0.000000
# 50%                    100.030000            0.000000          0.000000
# 75%                    100.180000            0.000000        262.000000
# max                    100.780000           12.221000       1298.000000
#
#        relative_humidity_(-)  temperature_(degrees_Celsius)  \
# count          472513.000000                  472513.000000
# mean                0.864811                      26.435772
# std                 0.136954                       3.644940
# min                 0.110000                      13.300000
# 25%                 0.790000                      23.700000
# 50%                 0.910000                      25.400000
# 75%                 0.970000                      28.800000
# max                 1.000000                      38.600000
#
#        wind_direction_(degrees)  wind_gusts_(m/s)  wind_speed_(m/s)
# count             472513.000000     472513.000000     472513.000000
# mean                 188.580020          1.236365          0.583630
# std                  100.191129          0.744814          0.333068
# min                    0.000000          0.000000          0.000000
# 25%                   97.000000          0.700000          0.300000
# 50%                  209.000000          1.070000          0.500000
# 75%                  268.000000          1.600000          0.780000
# max                  359.000000         11.490000          8.800000

# %%
df1_code = metadata['station_code'].unique()[2]

# %%
df1['station_code'] = df1_code

# %%
df1.head()
# Out:
#       timestamp_(UTC)  atmospheric_pressure_(kPa)  precipitation_(mm)  \
# 0 2015-08-19 09:40:00                      100.47                 0.0
# 1 2015-08-19 09:45:00                      100.47                 0.0
# 2 2015-08-19 09:50:00                      100.47                 0.0
# 3 2015-08-19 09:55:00                      100.47                 0.0
# 4 2015-08-19 10:00:00                      100.47                 0.0
#
#    radiation_(W/m2)  relative_humidity_(-)  temperature_(degrees_Celsius)  \
# 0              71.0                   0.82                           25.3
# 1               0.0                   0.82                           25.4
# 2               0.0                   0.82                           25.5
# 3               0.0                   0.82                           25.6
# 4               0.0                   0.81                           25.8
#
#    wind_direction_(degrees)  wind_gusts_(m/s)  wind_speed_(m/s) station_code
# 0                     237.0               1.6               0.4      TA00006
# 1                     212.0               1.1               0.1      TA00006
# 2                     286.0               0.1               0.0      TA00006
# 3                     281.0               0.1               0.0      TA00006
# 4                     275.0               0.1               0.1      TA00006

# %%
weather_df1 = df1.merge(metadata, how='left', on='station_code')

# %%
weather_df1.head()
# Out:
#       timestamp_(UTC)  atmospheric_pressure_(kPa)  precipitation_(mm)  \
# 0 2015-08-19 09:40:00                      100.47                 0.0
# 1 2015-08-19 09:45:00                      100.47                 0.0
# 2 2015-08-19 09:50:00                      100.47                 0.0
# 3 2015-08-19 09:55:00                      100.47                 0.0
# 4 2015-08-19 10:00:00                      100.47                 0.0
#
#    radiation_(W/m2)  relative_humidity_(-)  temperature_(degrees_Celsius)  \
# 0              71.0                   0.82                           25.3
# 1               0.0                   0.82                           25.4
# 2               0.0                   0.82                           25.5
# 3               0.0                   0.82                           25.6
# 4               0.0                   0.81                           25.8
#
#    wind_direction_(degrees)  wind_gusts_(m/s)  wind_speed_(m/s) station_code  \
# 0                     237.0               1.6               0.4      TA00006
# 1                     212.0               1.1               0.1      TA00006
# 2                     286.0               0.1               0.0      TA00006
# 3                     281.0               0.1               0.0      TA00006
# 4                     275.0               0.1               0.1      TA00006
#
#                      name country  installation_height_(m)  latitude  \
# 0  Nana Brentu SHTS Enchi      GH                        2  5.811292
# 1  Nana Brentu SHTS Enchi      GH                        2  5.811292
# 2  Nana Brentu SHTS Enchi      GH                        2  5.811292
# 3  Nana Brentu SHTS Enchi      GH                        2  5.811292
# 4  Nana Brentu SHTS Enchi      GH                        2  5.811292
#
#    longitude  elevation_(m)      timezone
# 0  -2.825617            139  Africa/Accra
# 1  -2.825617            139  Africa/Accra
# 2  -2.825617            139  Africa/Accra
# 3  -2.825617            139  Africa/Accra
# 4  -2.825617            139  Africa/Accra

# %%
weather_df1.to_csv('data/clean/enchi.csv', index=False)

# %%
df2.head()
# Out:
#     timestamp (UTC)  atmosphericpressure (kPa)  precipitation (mm)  \
# 0  2015-08-25 14:10                      97.93                1.19
# 1  2015-08-25 14:15                      97.91                0.00
# 2  2015-08-25 14:20                      97.91                0.02
# 3  2015-08-25 14:25                      97.91                0.00
# 4  2015-08-25 14:30                      97.90                0.00
#
#    radiation (W/m2)  relativehumidity (-)  temperature (degrees Celsius)  \
# 0             308.0                  0.70                           29.0
# 1             540.0                  0.70                           29.0
# 2             286.0                  0.70                           29.0
# 3             304.0                  0.71                           28.4
# 4             260.0                  0.73                           27.9
#
#    winddirection (degrees)  windgusts (m/s)  windspeed (m/s)
# 0                     55.0              2.3              0.8
# 1                     74.0              1.1              0.7
# 2                     75.0              3.1              1.0
# 3                    168.0              2.3              1.4
# 4                    172.0              2.0              1.5

# %%
df2.tail()
# Out:
#          timestamp (UTC)  atmosphericpressure (kPa)  precipitation (mm)  \
# 513122  2020-10-07 11:50                      98.05                 0.0
# 513123  2020-10-07 11:55                      98.03                 0.0
# 513124  2020-10-07 12:00                      98.02                 0.0
# 513125  2020-10-07 12:05                      98.00                 0.0
# 513126  2020-10-07 12:10                      97.98                 0.0
#
#         radiation (W/m2)  relativehumidity (-)  temperature (degrees Celsius)  \
# 513122             945.0                 0.764                           27.9
# 513123             975.0                 0.751                           28.3
# 513124             951.0                 0.747                           28.3
# 513125             954.0                 0.724                           28.6
# 513126             288.0                 0.761                           28.1
#
#         winddirection (degrees)  windgusts (m/s)  windspeed (m/s)
# 513122                    166.0             1.16             0.74
# 513123                    165.0             1.64             0.64
# 513124                    133.0             1.13             0.70
# 513125                    131.0             1.92             0.90
# 513126                    113.0             1.84             0.74

# %%
df2.columns
# Out:
# Index(['timestamp (UTC)', 'atmosphericpressure (kPa)', 'precipitation (mm)',
#        'radiation (W/m2)', 'relativehumidity (-)',
#        'temperature (degrees Celsius)', 'winddirection (degrees)',
#        'windgusts (m/s)', 'windspeed (m/s)'],
#       dtype='object')

# %%
df2.rename(columns={'timestamp (UTC)': 'timestamp_(UTC)', 
                              'atmosphericpressure (kPa)': 'atmospheric_pressure_(kPa)', 
                              'precipitation (mm)': 'precipitation_(mm)',
                              'radiation (W/m2)': 'radiation_(W/m2)', 
                              'relativehumidity (-)': 'relative_humidity_(-)',
                              'temperature (degrees Celsius)': 'temperature_(degrees_Celsius)', 
                              'winddirection (degrees)': 'wind_direction_(degrees)',
                              'windgusts (m/s)': 'wind_gusts_(m/s)', 
                              'windspeed (m/s)': 'wind_speed_(m/s)'
                             }, inplace=True)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 513127 entries, 0 to 513126
# Data columns (total 9 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   timestamp_(UTC)                513127 non-null  object
#  1   atmospheric_pressure_(kPa)     513122 non-null  float64
#  2   precipitation_(mm)             262486 non-null  float64
#  3   radiation_(W/m2)               505062 non-null  float64
#  4   relative_humidity_(-)          512991 non-null  float64
#  5   temperature_(degrees_Celsius)  512718 non-null  float64
#  6   wind_direction_(degrees)       504481 non-null  float64
#  7   wind_gusts_(m/s)               504138 non-null  float64
#  8   wind_speed_(m/s)               504481 non-null  float64
# dtypes: float64(8), object(1)
# memory usage: 35.2+ MB

# %%
df2.duplicated().sum()
# Out:
# 0

# %%
df2['timestamp_(UTC)'] = pd.to_datetime(df2['timestamp_(UTC)'])

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 513127 entries, 0 to 513126
# Data columns (total 9 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   timestamp_(UTC)                513127 non-null  datetime64[ns]
#  1   atmospheric_pressure_(kPa)     513122 non-null  float64
#  2   precipitation_(mm)             262486 non-null  float64
#  3   radiation_(W/m2)               505062 non-null  float64
#  4   relative_humidity_(-)          512991 non-null  float64
#  5   temperature_(degrees_Celsius)  512718 non-null  float64
#  6   wind_direction_(degrees)       504481 non-null  float64
#  7   wind_gusts_(m/s)               504138 non-null  float64
#  8   wind_speed_(m/s)               504481 non-null  float64
# dtypes: datetime64[ns](1), float64(8)
# memory usage: 35.2 MB

# %%
df2.describe()
# Out:
#        atmospheric_pressure_(kPa)  precipitation_(mm)  radiation_(W/m2)  \
# count               513122.000000       262486.000000     505062.000000
# mean                    97.859434            0.011155        151.025353
# std                      0.243451            0.184486        224.960250
# min                     96.490000            0.000000          0.000000
# 25%                     97.710000            0.000000          0.000000
# 50%                     97.880000            0.000000          0.000000
# 75%                     98.030000            0.000000        255.000000
# max                     98.620000           13.413000       1317.000000
#
#        relative_humidity_(-)  temperature_(degrees_Celsius)  \
# count          512991.000000                  512718.000000
# mean                0.757111                      26.995369
# std                 0.198980                       4.537953
# min                 0.080000                      14.200000
# 25%                 0.640000                      23.400000
# 50%                 0.830000                      25.700000
# 75%                 0.910000                      30.100000
# max                 1.000000                      44.600000
#
#        wind_direction_(degrees)  wind_gusts_(m/s)  wind_speed_(m/s)
# count             504481.000000     504138.000000     504481.000000
# mean                 149.643372          1.101236          0.472045
# std                   72.291819          0.681656          0.290695
# min                    0.000000          0.000000          0.000000
# 25%                  100.000000          0.600000          0.300000
# 50%                  154.000000          1.000000          0.400000
# 75%                  199.000000          1.490000          0.600000
# max                  359.000000         12.400000          4.800000

# %%
# Drop rows with any NA value to avoid us guessing values that might be wrong
df2.dropna(inplace=True)

# %%
df2.describe()
# Out:
#        atmospheric_pressure_(kPa)  precipitation_(mm)  radiation_(W/m2)  \
# count               256407.000000       256407.000000     256407.000000
# mean                    97.864705            0.008906        152.397154
# std                      0.257328            0.156190        224.978431
# min                     96.490000            0.000000          0.000000
# 25%                     97.720000            0.000000          0.000000
# 50%                     97.890000            0.000000          2.000000
# 75%                     98.040000            0.000000        258.000000
# max                     98.620000           13.413000       1317.000000
#
#        relative_humidity_(-)  temperature_(degrees_Celsius)  \
# count          256407.000000                  256407.000000
# mean                0.758868                      26.974157
# std                 0.198105                       4.562467
# min                 0.100000                      14.200000
# 25%                 0.640000                      23.400000
# 50%                 0.820000                      25.700000
# 75%                 0.911000                      30.100000
# max                 1.000000                      44.600000
#
#        wind_direction_(degrees)  wind_gusts_(m/s)  wind_speed_(m/s)
# count             256407.000000     256407.000000     256407.000000
# mean                 144.491593          1.181269          0.534967
# std                   58.722737          0.684151          0.305348
# min                    0.000000          0.000000          0.000000
# 25%                  116.000000          0.700000          0.300000
# 50%                  147.000000          1.060000          0.500000
# 75%                  170.000000          1.530000          0.700000
# max                  359.000000         12.400000          4.800000

# %%
df2_code = metadata['station_code'].unique()[3]

# %%
df2['station_code'] = df2_code

# %%
df2.head()
# Out:
#       timestamp_(UTC)  atmospheric_pressure_(kPa)  precipitation_(mm)  \
# 0 2015-08-25 14:10:00                       97.93                1.19
# 1 2015-08-25 14:15:00                       97.91                0.00
# 2 2015-08-25 14:20:00                       97.91                0.02
# 3 2015-08-25 14:25:00                       97.91                0.00
# 4 2015-08-25 14:30:00                       97.90                0.00
#
#    radiation_(W/m2)  relative_humidity_(-)  temperature_(degrees_Celsius)  \
# 0             308.0                   0.70                           29.0
# 1             540.0                   0.70                           29.0
# 2             286.0                   0.70                           29.0
# 3             304.0                   0.71                           28.4
# 4             260.0                   0.73                           27.9
#
#    wind_direction_(degrees)  wind_gusts_(m/s)  wind_speed_(m/s) station_code
# 0                      55.0               2.3               0.8      TA00009
# 1                      74.0               1.1               0.7      TA00009
# 2                      75.0               3.1               1.0      TA00009
# 3                     168.0               2.3               1.4      TA00009
# 4                     172.0               2.0               1.5      TA00009

# %%
weather_df2 = df2.merge(metadata, how='left', on='station_code')

# %%
weather_df2.head()
# Out:
#       timestamp_(UTC)  atmospheric_pressure_(kPa)  precipitation_(mm)  \
# 0 2015-08-25 14:10:00                       97.93                1.19
# 1 2015-08-25 14:15:00                       97.91                0.00
# 2 2015-08-25 14:20:00                       97.91                0.02
# 3 2015-08-25 14:25:00                       97.91                0.00
# 4 2015-08-25 14:30:00                       97.90                0.00
#
#    radiation_(W/m2)  relative_humidity_(-)  temperature_(degrees_Celsius)  \
# 0             308.0                   0.70                           29.0
# 1             540.0                   0.70                           29.0
# 2             286.0                   0.70                           29.0
# 3             304.0                   0.71                           28.4
# 4             260.0                   0.73                           27.9
#
#    wind_direction_(degrees)  wind_gusts_(m/s)  wind_speed_(m/s) station_code  \
# 0                      55.0               2.3               0.8      TA00009
# 1                      74.0               1.1               0.7      TA00009
# 2                      75.0               3.1               1.0      TA00009
# 3                     168.0               2.3               1.4      TA00009
# 4                     172.0               2.0               1.5      TA00009
#
#                   name country  installation_height_(m)  latitude  longitude  \
# 0  Adehyeman SHS Amasu      GH                        2  7.224886  -2.782252
# 1  Adehyeman SHS Amasu      GH                        2  7.224886  -2.782252
# 2  Adehyeman SHS Amasu      GH                        2  7.224886  -2.782252
# 3  Adehyeman SHS Amasu      GH                        2  7.224886  -2.782252
# 4  Adehyeman SHS Amasu      GH                        2  7.224886  -2.782252
#
#    elevation_(m)      timezone
# 0            319  Africa/Accra
# 1            319  Africa/Accra
# 2            319  Africa/Accra
# 3            319  Africa/Accra
# 4            319  Africa/Accra

# %%
weather_df2.to_csv('data/clean/amasu.csv', index=False)

# %%
df3.head()
# Out:
#     timestamp (UTC)  atmosphericpressure (kPa)  precipitation (mm)  \
# 0  2016-11-18 15:15                        NaN                 NaN
# 1  2016-11-18 15:20                        NaN                 NaN
# 2  2016-11-18 15:25                        NaN                 NaN
# 3  2016-11-18 15:30                        NaN                 NaN
# 4  2016-11-18 15:35                        NaN                 NaN
#
#    radiation (W/m2)  relativehumidity (-)  temperature (degrees Celsius)  \
# 0               0.0                   NaN                            NaN
# 1               0.0                   NaN                            NaN
# 2               0.0                   NaN                            NaN
# 3               0.0                   NaN                            NaN
# 4               0.0                   NaN                            NaN
#
#    winddirection (degrees)  windgusts (m/s)  windspeed (m/s)
# 0                     63.0              0.0              0.0
# 1                     40.0              0.0              0.0
# 2                     89.0              0.0              0.0
# 3                     51.0              0.0              0.0
# 4                     91.0              0.0              0.0

# %%
df3.tail()
# Out:
#          timestamp (UTC)  atmosphericpressure (kPa)  precipitation (mm)  \
# 332899  2020-10-07 12:40                      98.25                 0.0
# 332900  2020-10-07 12:45                      98.25                 0.0
# 332901  2020-10-07 12:50                      98.24                 0.0
# 332902  2020-10-07 12:55                      98.23                 0.0
# 332903  2020-10-07 13:00                      98.23                 0.0
#
#         radiation (W/m2)  relativehumidity (-)  temperature (degrees Celsius)  \
# 332899             728.0                 0.928                           26.3
# 332900             648.0                 0.967                           25.9
# 332901             824.0                 0.934                           26.4
# 332902             858.0                 0.896                           27.2
# 332903             711.0                 0.926                           26.9
#
#         winddirection (degrees)  windgusts (m/s)  windspeed (m/s)
# 332899                     90.0             2.29             0.86
# 332900                    132.0             2.09             1.18
# 332901                    175.0             2.68             1.29
# 332902                    210.0             2.90             0.88
# 332903                    193.0             4.31             1.53

# %%
df3.columns
# Out:
# Index(['timestamp (UTC)', 'atmosphericpressure (kPa)', 'precipitation (mm)',
#        'radiation (W/m2)', 'relativehumidity (-)',
#        'temperature (degrees Celsius)', 'winddirection (degrees)',
#        'windgusts (m/s)', 'windspeed (m/s)'],
#       dtype='object')

# %%
df3.rename(columns={'timestamp (UTC)': 'timestamp_(UTC)', 
                              'atmosphericpressure (kPa)': 'atmospheric_pressure_(kPa)', 
                              'precipitation (mm)': 'precipitation_(mm)',
                              'radiation (W/m2)': 'radiation_(W/m2)', 
                              'relativehumidity (-)': 'relative_humidity_(-)',
                              'temperature (degrees Celsius)': 'temperature_(degrees_Celsius)', 
                              'winddirection (degrees)': 'wind_direction_(degrees)',
                              'windgusts (m/s)': 'wind_gusts_(m/s)', 
                              'windspeed (m/s)': 'wind_speed_(m/s)'
                             }, inplace=True)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 332904 entries, 0 to 332903
# Data columns (total 9 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   timestamp_(UTC)                332904 non-null  object
#  1   atmospheric_pressure_(kPa)     303013 non-null  float64
#  2   precipitation_(mm)             286778 non-null  float64
#  3   radiation_(W/m2)               332886 non-null  float64
#  4   relative_humidity_(-)          300062 non-null  float64
#  5   temperature_(degrees_Celsius)  305182 non-null  float64
#  6   wind_direction_(degrees)       319278 non-null  float64
#  7   wind_gusts_(m/s)               317652 non-null  float64
#  8   wind_speed_(m/s)               317638 non-null  float64
# dtypes: float64(8), object(1)
# memory usage: 22.9+ MB

# %%
df3.duplicated().sum()
# Out:
# 0

# %%
df3['timestamp_(UTC)'] = pd.to_datetime(df3['timestamp_(UTC)'])

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 332904 entries, 0 to 332903
# Data columns (total 9 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   timestamp_(UTC)                332904 non-null  datetime64[ns]
#  1   atmospheric_pressure_(kPa)     303013 non-null  float64
#  2   precipitation_(mm)             286778 non-null  float64
#  3   radiation_(W/m2)               332886 non-null  float64
#  4   relative_humidity_(-)          300062 non-null  float64
#  5   temperature_(degrees_Celsius)  305182 non-null  float64
#  6   wind_direction_(degrees)       319278 non-null  float64
#  7   wind_gusts_(m/s)               317652 non-null  float64
#  8   wind_speed_(m/s)               317638 non-null  float64
# dtypes: datetime64[ns](1), float64(8)
# memory usage: 22.9 MB

# %%
df3.describe()
# Out:
#        atmospheric_pressure_(kPa)  precipitation_(mm)  radiation_(W/m2)  \
# count               303013.000000       286778.000000     332886.000000
# mean                    98.163176            0.064695        142.926876
# std                      1.138992            1.156193        229.868666
# min                     79.010000            0.000000          0.000000
# 25%                     98.110000            0.000000          0.000000
# 50%                     98.260000            0.000000          0.000000
# 75%                     98.400000            0.000000        226.000000
# max                    101.280000           33.680000       1185.000000
#
#        relative_humidity_(-)  temperature_(degrees_Celsius)  \
# count          300062.000000                  305182.000000
# mean                0.842646                      25.615532
# std                 0.141123                       5.453286
# min                 0.040000                     -14.400000
# 25%                 0.769000                      23.500000
# 50%                 0.890000                      25.300000
# 75%                 0.943000                      28.400000
# max                 1.000000                      38.600000
#
#        wind_direction_(degrees)  wind_gusts_(m/s)  wind_speed_(m/s)
# count             319278.000000     317652.000000     317638.000000
# mean                 177.624738          1.483868          0.642541
# std                   81.241996          2.271994          0.778888
# min                    0.000000          0.000000          0.000000
# 25%                  130.000000          0.640000          0.330000
# 50%                  193.000000          1.350000          0.610000
# 75%                  236.000000          2.020000          0.890000
# max                  359.000000         60.000000         39.920000

# %%
# Drop rows with any NA value to avoid us guessing values that might be wrong
df3.dropna(inplace=True)

# %%
df3.describe()
# Out:
#        atmospheric_pressure_(kPa)  precipitation_(mm)  radiation_(W/m2)  \
# count               272379.000000       272379.000000     272379.000000
# mean                    98.261730            0.008593        162.254939
# std                      0.204135            0.147917        236.968085
# min                     97.480000            0.000000          0.000000
# 25%                     98.120000            0.000000          0.000000
# 50%                     98.270000            0.000000          6.000000
# 75%                     98.400000            0.000000        276.000000
# max                     98.930000           12.834000       1185.000000
#
#        relative_humidity_(-)  temperature_(degrees_Celsius)  \
# count          272379.000000                  272379.000000
# mean                0.839784                      26.230995
# std                 0.134582                       3.196194
# min                 0.173000                      16.900000
# 25%                 0.767000                      23.700000
# 50%                 0.884000                      25.500000
# 75%                 0.939000                      28.500000
# max                 1.000000                      37.400000
#
#        wind_direction_(degrees)  wind_gusts_(m/s)  wind_speed_(m/s)
# count             272379.000000     272379.000000     272379.000000
# mean                 193.255376          1.566378          0.699439
# std                   66.946475          1.004362          0.486234
# min                    0.000000          0.080000          0.040000
# 25%                  150.000000          0.870000          0.420000
# 50%                  202.000000          1.470000          0.660000
# 75%                  241.000000          2.090000          0.920000
# max                  359.000000         60.000000         38.740000

# %%
df3_code = metadata['station_code'].unique()[1]

# %%
df3['station_code'] = df3_code

# %%
df3.head()
# Out:
#           timestamp_(UTC)  atmospheric_pressure_(kPa)  precipitation_(mm)  \
# 44885 2017-05-06 00:05:00                       98.34                 0.0
# 44886 2017-05-06 00:10:00                       98.34                 0.0
# 44887 2017-05-06 00:15:00                       98.35                 0.0
# 44888 2017-05-06 00:20:00                       98.34                 0.0
# 44889 2017-05-06 00:25:00                       98.32                 0.0
#
#        radiation_(W/m2)  relative_humidity_(-)  temperature_(degrees_Celsius)  \
# 44885               0.0                  0.908                           24.7
# 44886               0.0                  0.908                           24.7
# 44887               0.0                  0.910                           24.7
# 44888               0.0                  0.915                           24.6
# 44889               0.0                  0.924                           24.5
#
#        wind_direction_(degrees)  wind_gusts_(m/s)  wind_speed_(m/s)  \
# 44885                     244.0              0.57              0.30
# 44886                     241.0              0.78              0.37
# 44887                     229.0              0.76              0.27
# 44888                     195.0              0.79              0.33
# 44889                     104.0              0.90              0.41
#
#       station_code
# 44885      TA00039
# 44886      TA00039
# 44887      TA00039
# 44888      TA00039
# 44889      TA00039

# %%
weather_df3 = df3.merge(metadata, how='left', on='station_code')

# %%
weather_df3.head()
# Out:
#       timestamp_(UTC)  atmospheric_pressure_(kPa)  precipitation_(mm)  \
# 0 2017-05-06 00:05:00                       98.34                 0.0
# 1 2017-05-06 00:10:00                       98.34                 0.0
# 2 2017-05-06 00:15:00                       98.35                 0.0
# 3 2017-05-06 00:20:00                       98.34                 0.0
# 4 2017-05-06 00:25:00                       98.32                 0.0
#
#    radiation_(W/m2)  relative_humidity_(-)  temperature_(degrees_Celsius)  \
# 0               0.0                  0.908                           24.7
# 1               0.0                  0.908                           24.7
# 2               0.0                  0.910                           24.7
# 3               0.0                  0.915                           24.6
# 4               0.0                  0.924                           24.5
#
#    wind_direction_(degrees)  wind_gusts_(m/s)  wind_speed_(m/s) station_code  \
# 0                     244.0              0.57              0.30      TA00039
# 1                     241.0              0.78              0.37      TA00039
# 2                     229.0              0.76              0.27      TA00039
# 3                     195.0              0.79              0.33      TA00039
# 4                     104.0              0.90              0.41      TA00039
#
#                name country  installation_height_(m)  latitude  longitude  \
# 0  KNUST JHS Kumasi      GH                        2  6.684167  -1.568333
# 1  KNUST JHS Kumasi      GH                        2  6.684167  -1.568333
# 2  KNUST JHS Kumasi      GH                        2  6.684167  -1.568333
# 3  KNUST JHS Kumasi      GH                        2  6.684167  -1.568333
# 4  KNUST JHS Kumasi      GH                        2  6.684167  -1.568333
#
#    elevation_(m)      timezone
# 0            302  Africa/Accra
# 1            302  Africa/Accra
# 2            302  Africa/Accra
# 3            302  Africa/Accra
# 4            302  Africa/Accra

# %%
weather_df3.to_csv('data/clean/kumasi.csv', index=False)
